# %%
#datatypes in python
#python having 3 data types
#1.Int(integer)
#2.str(string or charecters)
#3.float(decimals)

# %%
a=10
b="muneesh"
c=1000000.25
print(a)
print(b)
print(c)

print(type(a))
print(type(c))
print(type(b))
# Out:
# 10
# muneesh
# 1000000.25
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
a=100
b=200
print(a+b)
# Out:
# 300

# %%
#operators in python
#1.Arthematic operators
#2.Assignment operators
#3.Comparasion operators
#4.Logical operators
#5.membership operators
#6.identity operators

# %%
#Arthematic operators
a=100
b=50
c=300
print(a+b)
print(b-c)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# 150
# -250
# 5000
# 2.0
# 2
# 0

# %%
#Assignment operators
a=100
a=a+45
print(a)
# Out:
# 145

# %%
a=100
a=a-45
print(a)
# Out:
# 55

# %%
a=148
a=a*123/234
print(a)
# Out:
# 77.7948717948718

# %%
#comparision operators
a=100
b=50
c=50
print(a>b)
print(a<c)
print(b==c)
print(a!=b) 
print(a>=c)
print(a<=c)
# Out:
# True
# False
# True
# True
# True
# False

# %%
#logical operators-and,or,not
"""
and logical truth table - all coditions are true then result is true or else result is false

"""

# %%
names=("shivaji","vikas","raj","alok")
print("chandra"in names)
print("vikram"not in names)
print("shivaji" in names)
# Out:
# False
# True
# True

# %%
"""
Identity operators-is, is not
in python each value has some identity based on machines and validiting Tru or False
"""
a=10000
b=10000
print(id(a))
print(id(b))
print(a is b)
# Out:
# 4425319600
# 4425319344
# False

# %%
a=10
b=10
print(id(a))
print(id(b))
print(a is b)
# Out:
# 4387579992
# 4387579992
# True
