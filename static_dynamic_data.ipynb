# %%
#Static data type in python
name="shivaji"
age=26
salary=10000.65
print("my name ",name)
print("my age is",age)
print("my salary is ",salary)
# Out:
# my name  shivaji
# my age is 26
# my salary is  10000.65

# %%
#Addition of 2 numbers using dynamic data type
a=int(input("enter first nnumber here:"))
b=int(input("enter second number here:"))
c=a+b
print("The Sum is",c)
# Out:
# The Sum is 612

# %%
#Addition of first and last name using dynamic data type
n=str(input("enter first name here:"))
m=str(input("enter last name here:"))
x=n+m
print("The Sum is",x)
# Out:
# The Sum is Muneesh Reddy

# %%
#Addition of 2 Float numbers using dynamic data type
a=float(input("enter first Float Number here:"))
b=float(input("enter second Float Number here:"))
c=a+b
print("The Sum is",c)
# Out:
# The Sum is 46134.399999999994
